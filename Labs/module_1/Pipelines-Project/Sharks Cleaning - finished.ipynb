# %%
# 1. Importing file sharks and making a copy:

import pandas as pd
import os

os.chdir('C:/Users/Kasia/TEST/806_Repo/Labs/module_1/Pipelines-Project/204_47432_compressed_attacks')
sharks=pd.read_csv("attacks.csv", encoding='latin-1')
data = sharks.copy()

# %%
# 2. Examining data:
data.head()
# Out:
#   Case Number         Date    Year        Type    Country             Area  \
# 0  2018.06.25  25-Jun-2018  2018.0     Boating        USA       California
# 1  2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA          Georgia
# 2  2018.06.09  09-Jun-2018  2018.0     Invalid        USA           Hawaii
# 3  2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 4  2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO           Colima
#
#                          Location     Activity             Name Sex   ...  \
# 0     Oceanside, San Diego County     Paddling      Julie Wolfe    F  ...
# 1  St. Simon Island, Glynn County     Standing  Adyson McNeely     F  ...
# 2                    Habush, Oahu      Surfing      John Denges    M  ...
# 3              Arrawarra Headland      Surfing             male    M  ...
# 4                        La Ticla  Free diving   Gustavo Ramos     M  ...
#
#           Species           Investigator or Source                       pdf  \
# 0      White shark                R. Collier, GSAF      2018.06.25-Wolfe.pdf
# 1              NaN  K.McMurray, TrackingSharks.com    2018.06.18-McNeely.pdf
# 2              NaN  K.McMurray, TrackingSharks.com     2018.06.09-Denges.pdf
# 3        2 m shark                  B. Myatt, GSAF  2018.06.08-Arrawarra.pdf
# 4  Tiger shark, 3m                       A .Kipper      2018.06.04-Ramos.pdf
#
#                                         href formula  \
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1  http://sharkattackfile.net/spreadsheets/pdf_di...
# 2  http://sharkattackfile.net/spreadsheets/pdf_di...
# 3  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                 href Case Number.1  \
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.25
# 1  http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.18
# 2  http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.09
# 3  http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.08
# 4  http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.04
#
#   Case Number.2 original order Unnamed: 22 Unnamed: 23
# 0    2018.06.25         6303.0         NaN         NaN
# 1    2018.06.18         6302.0         NaN         NaN
# 2    2018.06.09         6301.0         NaN         NaN
# 3    2018.06.08         6300.0         NaN         NaN
# 4    2018.06.04         6299.0         NaN         NaN
#
# [5 rows x 24 columns]

# %%
data.shape
# Out:
# (25723, 24)

# %%
data.columns
# Out:
# Index(['Case Number', 'Date', 'Year', 'Type', 'Country', 'Area', 'Location',
#        'Activity', 'Name', 'Sex ', 'Age', 'Injury', 'Fatal (Y/N)', 'Time',
#        'Species ', 'Investigator or Source', 'pdf', 'href formula', 'href',
#        'Case Number.1', 'Case Number.2', 'original order', 'Unnamed: 22',
#        'Unnamed: 23'],
#       dtype='object')

# %%
#checking what unique values I have in each column to get more idea of what I have in my data:
data["Injury"].unique()
# Out:
# array(['No injury to occupant, outrigger canoe and paddle damaged',
#        'Minor injury to left thigh',
#        'Injury to left lower leg from surfboard skeg', ...,
#        'FATAL, leg stripped of flesh  ',
#        'FATAL, knocked overboard by tail of shark & carried off by shark ',
#        'FATAL. "Shark bit him in half, carrying away the lower extremities" '],
#       dtype=object)

# %%
"""
3. After checking what my data looks like, I am defining my purpose of cleaning the data:

Travel agency is studying about best locations to organize water sports escapades.
They are asking me:
- which countries are to avoid when it comes to shark attacks danger;
- the risk that the shark attack will be fatal;
- if there is any seasonality in shark attacks, so they could avoid certain months.

So to my study, the most important columns are:
Country, Year - these cannot be nan
Fatal, Date - these, even if nan, I keep, bc they still give me info that there was an attack in specyfic country
"""
# Out:
# '\n3. After checking what my data looks like, I am defining my purpose of cleaning the data:\n\nTravel agency is studying about best locations to organize water sports escapades.\nThey are asking me:\n- which countries are to avoid when it comes to shark attacks danger;\n- the risk that the shark attack will be fatal;\n- if there is any seasonality in shark attacks, so they could avoid certain months.\n\nSo to my study, the most important columns are:\nCountry, Year - these cannot be nan\nFatal, Date - these, even if nan, I keep, bc they still give me info that there was an attack in specyfic country\n'

# %%
# 4. I decided to drop columns at the end of the pricess, bc even unnecessary columns I might need to clean necessary columns.
# ( I have learnt it hard way ;)

# %%
# 5. I will check if there are duplicated rows:

#data.duplicated(subset=["Date","Name","Location", "Injury","Time"])
data.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 25718     True
# 25719     True
# 25720     True
# 25721     True
# 25722    False
# Length: 25723, dtype: bool

# %%
# 6. Apparently there are exact duplicates, I will get rid of them:
data = data.drop_duplicates()
data.shape
# Out:
# (6312, 24)

# %%
# 7. If I understand well, there were 21k rows duplicated??? I hope I understand well...

# %%
# 8. Checking my important columns for unique values
data["Year"].unique()
# Out:
# array([2018., 2017.,   nan, 2016., 2015., 2014., 2013., 2012., 2011.,
#        2010., 2009., 2008., 2007., 2006., 2005., 2004., 2003., 2002.,
#        2001., 2000., 1999., 1998., 1997., 1996., 1995., 1984., 1994.,
#        1993., 1992., 1991., 1990., 1989., 1969., 1988., 1987., 1986.,
#        1985., 1983., 1982., 1981., 1980., 1979., 1978., 1977., 1976.,
#        1975., 1974., 1973., 1972., 1971., 1970., 1968., 1967., 1966.,
#        1965., 1964., 1963., 1962., 1961., 1960., 1959., 1958., 1957.,
#        1956., 1955., 1954., 1953., 1952., 1951., 1950., 1949., 1948.,
#        1848., 1947., 1946., 1945., 1944., 1943., 1942., 1941., 1940.,
#        1939., 1938., 1937., 1936., 1935., 1934., 1933., 1932., 1931.,
#        1930., 1929., 1928., 1927., 1926., 1925., 1924., 1923., 1922.,
#        1921., 1920., 1919., 1918., 1917., 1916., 1915., 1914., 1913.,
#        1912., 1911., 1910., 1909., 1908., 1907., 1906., 1905., 1904.,
#        1903., 1902., 1901., 1900., 1899., 1898., 1897., 1896., 1895.,
#        1894., 1893., 1892., 1891., 1890., 1889., 1888., 1887., 1886.,
#        1885., 1884., 1883., 1882., 1881., 1880., 1879., 1878., 1877.,
#        1876., 1875., 1874., 1873., 1872., 1871., 1870., 1869., 1868.,
#        1867., 1866., 1865., 1864., 1863., 1862., 1861., 1860., 1859.,
#        1858., 1857., 1856., 1855., 1853., 1852., 1851., 1850., 1849.,
#        1847., 1846., 1845., 1844., 1842., 1841., 1840., 1839., 1837.,
#        1836., 1835., 1834., 1832., 1831., 1830., 1829., 1828., 1827.,
#        1826., 1825., 1823., 1822., 1819., 1818., 1817., 1816., 1815.,
#        1812., 1811., 1810., 1808., 1807., 1805., 1804., 1803., 1802.,
#        1801., 1800., 1797., 1792., 1791., 1788., 1787., 1786., 1785.,
#        1784., 1783., 1780., 1779., 1776., 1771., 1767., 1764., 1758.,
#        1753., 1751., 1749., 1755., 1748., 1742., 1738., 1733., 1723.,
#        1721., 1703., 1700., 1642., 1638., 1637., 1617., 1595., 1580.,
#        1555., 1554., 1543.,  500.,   77.,    5.,    0.])

# %%
# 9. Will start with Year - it goes back to 1543:
indexNames = data[data['Year'] < 2000].index
data.drop(indexNames , inplace=True)
data["Year"].unique()
# Out:
# array([2018., 2017.,   nan, 2016., 2015., 2014., 2013., 2012., 2011.,
#        2010., 2009., 2008., 2007., 2006., 2005., 2004., 2003., 2002.,
#        2001., 2000.])

# %%
data.shape
# Out:
# (2090, 24)

# %%
# 10. Year column is essential to me (the migration of sharks every 20 years), so I will drop nans:
data.dropna(subset = ["Year"], inplace=True)
data["Year"].unique()
# Out:
# array([2018., 2017., 2016., 2015., 2014., 2013., 2012., 2011., 2010.,
#        2009., 2008., 2007., 2006., 2005., 2004., 2003., 2002., 2001.,
#        2000.])

# %%
data.shape
# Out:
# (2078, 24)

# %%
# 11. Checking Fatality column:
data["Fatal (Y/N)"].unique()
# Out:
# array(['N', 'Y', nan, 'M', 'UNKNOWN', '2017'], dtype=object)

# %%
# 12. Will clean values:
data["Fatal (Y/N)"] = data["Fatal (Y/N)"].str.replace('M', 'N')
data.["Fatal (Y/N)"].unique()
# Out:
#   File "<ipython-input-95-0dbea2ab1270>", line 3
#     data.["Fatal (Y/N)"].unique()
#          ^
# SyntaxError: invalid syntax

# %%
# 13. I constate that having spaces in col name is not a good thing, will rename this column first:
data = data.rename(columns={'Fatal (Y/N)':'Fatality'})
# 14. and clean the M/N:
data["Fatality"] = data["Fatality"].str.replace('M', 'N')
data.Fatality.unique()
# Out:
# array(['N', 'Y', nan, 'UNKNOWN', '2017'], dtype=object)

# %%
# 15. 
data.Fatality.value_counts()
# Out:
# N          1739
# Y           175
# UNKNOWN       2
# 2017          1
# Name: Fatality, dtype: int64

# %%
# 16. looks good, 3 values that is tempting to drop/leave them, but let s see if possible to correct them:
# question in my head, shall i drop these 3 rows of nan or keep the for the sake of other info in the row?
#I will keep them for now
data.loc[data['Fatality'] == "2017"]
# Out:
#     Case Number         Date    Year      Type Country      Area  Location  \
# 786  2012.06.10  10-Jun-2012  2012.0  Provoked   ITALY  Sardinia  Muravera
#
#                                             Activity          Name Sex   ...  \
# 786  Attempting to rescue an injured & beached shark  Giorgio Zara    M  ...
#
#              Species  Investigator or Source                  pdf  \
# 786  Blue shark, 2.5m    D. Puddo, 6/11/2012  2012.06.10-Zara.pdf
#
#                                           href formula  \
# 786  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                   href Case Number.1  \
# 786  http://sharkattackfile.net/spreadsheets/pdf_di...    2012.06.10
#
#     Case Number.2 original order Unnamed: 22 Unnamed: 23
# 786    2012.06.10         5517.0         NaN         NaN
#
# [1 rows x 24 columns]

# %%
# 16a
data.loc[data['Fatality'] == "UNKNOWN"]
# Out:
#        Case Number         Date    Year        Type    Country  \
# 624     2013.09.08  08-Sep-2013  2013.0  Unprovoked        USA
# 1270  2008.04.20.a  20-Apr-2008  2008.0  Unprovoked  AUSTRALIA
#
#                  Area                            Location Activity  \
# 624    South Carolina  St. Helena Island, Beaufort County      NaN
# 1270  New South Wales                       Crescent Head      NaN
#
#                  Name Sex   ...            Species  Investigator or Source  \
# 624            female    F  ...                 NaN       WIS-TV, 9/9/2013
# 1270  Jamie Adlington    M  ...  Tiger shark, 2.3m          T. Peake, GSAF
#
#                              pdf  \
# 624     2013.09.08-St-Helena.pdf
# 1270  2008.04.20.a-Adlington.pdf
#
#                                            href formula  \
# 624   http://sharkattackfile.net/spreadsheets/pdf_di...
# 1270  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                    href Case Number.1  \
# 624   http://sharkattackfile.net/spreadsheets/pdf_di...    2013.09.08
# 1270  http://sharkattackfile.net/spreadsheets/pdf_di...  2008.04.20.a
#
#      Case Number.2 original order Unnamed: 22 Unnamed: 23
# 624     2013.09.08         5679.0         NaN         NaN
# 1270  2008.04.20.a         5033.0         NaN         NaN
#
# [2 rows x 24 columns]

# %%
# 17. seems like 2017 was not fatal, lets correct it:
data["Fatality"] = data["Fatality"].str.replace('2017', 'N')
data['Fatality'] = data['Fatality'].fillna("UNKNOWN")
data.Fatality.unique()
# Out:
# array(['N', 'Y', 'UNKNOWN'], dtype=object)

# %%
# 17a
# ok, looks good, but it wasnt piece of cake, been struggling with:
#NameError: name 'nan' is not defined, imported numby but it didnt help, then was this:
#TypeError: repl must be a string or callable
# grrrrr, I will change my nan to UNKNOWN instead:
#data['Fatality'] = data['Fatality'].fillna("UNKNOWN")
#data["Fatality"] = data["Fatality"].str.replace('','UNKNOWN')
#data.Fatality.unique()
#array(['UNKNOWNUUNKNOWNNUNKNOWNKUNKNOWNNUNKNOWNOUNKNOWNWUNKNOWNNUNKNOWNNUNKNOWNUUNKNOWNNUNKNOWNKUNKNOWNNUNKNOWNOUNKNOWNWUNKNOWNNUNKNOWN',
 #      'UNKNOWNUUNKNOWNNUNKNOWNKUNKNOWNNUNKNOWNOUNKNOWNWUNKNOWNNUNKNOWNYUNKNOWNUUNKNOWNNUNKNOWNKUNKNOWNNUNKNOWNOUNKNOWNWUNKNOWNNUNKNOWN',
  #     '...',
   #    'UNKNOWNUUNKNOWNNUNKNOWNKUNKNOWNNUNKNOWNOUNKNOWNWUNKNOWNNUNKNOWN'],
    #  dtype=object)

# %%
# 18. I will now work on Country column:
data["Country"].unique()
# Out:
# array(['USA', 'AUSTRALIA', 'MEXICO', 'BRAZIL', 'ENGLAND', 'SOUTH AFRICA',
#        'THAILAND', 'COSTA RICA', 'MALDIVES', 'BAHAMAS', 'NEW CALEDONIA',
#        'ECUADOR', 'MALAYSIA', 'LIBYA', nan, 'CUBA', 'MAURITIUS',
#        'NEW ZEALAND', 'SPAIN', 'SAMOA', 'SOLOMON ISLANDS', 'JAPAN',
#        'EGYPT', 'ST HELENA, British overseas territory', 'COMOROS',
#        'REUNION', 'FRENCH POLYNESIA', 'UNITED KINGDOM',
#        'UNITED ARAB EMIRATES', 'PHILIPPINES', 'INDONESIA', 'CHINA',
#        'COLUMBIA', 'CAPE VERDE', 'Fiji', 'DOMINICAN REPUBLIC',
#        'CAYMAN ISLANDS', 'ARUBA', 'MOZAMBIQUE', 'FIJI', 'PUERTO RICO',
#        'ITALY', 'ATLANTIC OCEAN', 'GREECE', 'ST. MARTIN', 'FRANCE',
#        'PAPUA NEW GUINEA', 'TRINIDAD & TOBAGO', 'KIRIBATI', 'ISRAEL',
#        'DIEGO GARCIA', 'TAIWAN', 'JAMAICA', 'PALESTINIAN TERRITORIES',
#        'GUAM', 'SEYCHELLES', 'BELIZE', 'NIGERIA', 'TONGA', 'SCOTLAND',
#        'CANADA', 'CROATIA', 'SAUDI ARABIA', 'CHILE', 'ANTIGUA', 'KENYA',
#        'RUSSIA', 'TURKS & CAICOS', 'UNITED ARAB EMIRATES (UAE)', 'AZORES',
#        'SOUTH KOREA', 'MALTA', 'VIETNAM', 'MADAGASCAR', 'PANAMA',
#        'SOMALIA', 'NEVIS', 'BRITISH VIRGIN ISLANDS', 'NORWAY', 'SENEGAL',
#        'YEMEN', 'GULF OF ADEN', 'Sierra Leone', 'ST. MAARTIN',
#        'GRAND CAYMAN', 'Seychelles', 'LIBERIA', 'VANUATU', 'MEXICO ',
#        'HONDURAS', 'VENEZUELA', 'SRI LANKA', ' TONGA', 'URUGUAY', 'INDIA',
#        'MICRONESIA', 'CARIBBEAN SEA', 'OKINAWA', 'TANZANIA'], dtype=object)

# %%
# 19. It seems pretty clean to me, I will only 
# - change nans na UNMKNOWN
# - merge FIJI with Fiji
# - merge England with United Kingdom (eventhough missing some information)
data['Country'].fillna('UNKNOWN', inplace=True)
data['Country'] = data['Country'].str.strip().str.upper()
data["Country"] = data["Country"].str.replace('ENGLAND', 'NUNITED KINGDOM')
data["Country"].unique()
# Out:
# array(['USA', 'AUSTRALIA', 'MEXICO', 'BRAZIL', 'NUNITED KINGDOM',
#        'SOUTH AFRICA', 'THAILAND', 'COSTA RICA', 'MALDIVES', 'BAHAMAS',
#        'NEW CALEDONIA', 'ECUADOR', 'MALAYSIA', 'LIBYA', 'UNKNOWN', 'CUBA',
#        'MAURITIUS', 'NEW ZEALAND', 'SPAIN', 'SAMOA', 'SOLOMON ISLANDS',
#        'JAPAN', 'EGYPT', 'ST HELENA, BRITISH OVERSEAS TERRITORY',
#        'COMOROS', 'REUNION', 'FRENCH POLYNESIA', 'UNITED KINGDOM',
#        'UNITED ARAB EMIRATES', 'PHILIPPINES', 'INDONESIA', 'CHINA',
#        'COLUMBIA', 'CAPE VERDE', 'FIJI', 'DOMINICAN REPUBLIC',
#        'CAYMAN ISLANDS', 'ARUBA', 'MOZAMBIQUE', 'PUERTO RICO', 'ITALY',
#        'ATLANTIC OCEAN', 'GREECE', 'ST. MARTIN', 'FRANCE',
#        'PAPUA NEW GUINEA', 'TRINIDAD & TOBAGO', 'KIRIBATI', 'ISRAEL',
#        'DIEGO GARCIA', 'TAIWAN', 'JAMAICA', 'PALESTINIAN TERRITORIES',
#        'GUAM', 'SEYCHELLES', 'BELIZE', 'NIGERIA', 'TONGA', 'SCOTLAND',
#        'CANADA', 'CROATIA', 'SAUDI ARABIA', 'CHILE', 'ANTIGUA', 'KENYA',
#        'RUSSIA', 'TURKS & CAICOS', 'UNITED ARAB EMIRATES (UAE)', 'AZORES',
#        'SOUTH KOREA', 'MALTA', 'VIETNAM', 'MADAGASCAR', 'PANAMA',
#        'SOMALIA', 'NEVIS', 'BRITISH VIRGIN ISLANDS', 'NORWAY', 'SENEGAL',
#        'YEMEN', 'GULF OF ADEN', 'SIERRA LEONE', 'ST. MAARTIN',
#        'GRAND CAYMAN', 'LIBERIA', 'VANUATU', 'HONDURAS', 'VENEZUELA',
#        'SRI LANKA', 'URUGUAY', 'INDIA', 'MICRONESIA', 'CARIBBEAN SEA',
#        'OKINAWA', 'TANZANIA'], dtype=object)

# %%
# 20. I will check how many nans we have and if we can find the Country by its Area or Location column.
data.loc[data['Country'] == "UNKNOWN"]
# Out:
#       Case Number                  Date    Year        Type  Country Area  \
# 62   2017.11.13.R  Reported 13-Nov-2017  2017.0  Unprovoked  UNKNOWN  NaN
# 525    2014.08.00              Aug-2014  2014.0     Invalid  UNKNOWN  NaN
#
#     Location      Activity            Name Sex   ...  \
# 62       NaN       Surfing   Timur Yunusov    M  ...
# 525      NaN  Sea disaster  Cuban refugees    M  ...
#
#                             Species         Investigator or Source  \
# 62                               NaN                     Instagram
# 525  Shark involvement not confirmed  Associated Press, 11/27/2014
#
#                                pdf  \
# 62          2017.11.13.R-Timur.pdf
# 525  2014.08.00-Cuban-refugees.pdf
#
#                                           href formula  \
# 62   http://sharkattackfile.net/spreadsheets/pdf_di...
# 525  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                   href Case Number.1  \
# 62   http://sharkattackfile.net/spreadsheets/pdf_di...  2017.11.13.R
# 525  http://sharkattackfile.net/spreadsheets/pdf_di...    2014.08.00
#
#     Case Number.2 original order Unnamed: 22 Unnamed: 23
# 62   2017.11.13.R         6241.0         NaN         NaN
# 525    2014.08.00         5778.0         NaN         NaN
#
# [2 rows x 24 columns]

# %%
# 21.We can drop these 2 rows:
indexNames = data[data['Country'] == "UNKNOWN"].index
data.drop(indexNames , inplace=True)
data["Country"].unique()
# Out:
# array(['USA', 'AUSTRALIA', 'MEXICO', 'BRAZIL', 'NUNITED KINGDOM',
#        'SOUTH AFRICA', 'THAILAND', 'COSTA RICA', 'MALDIVES', 'BAHAMAS',
#        'NEW CALEDONIA', 'ECUADOR', 'MALAYSIA', 'LIBYA', 'CUBA',
#        'MAURITIUS', 'NEW ZEALAND', 'SPAIN', 'SAMOA', 'SOLOMON ISLANDS',
#        'JAPAN', 'EGYPT', 'ST HELENA, BRITISH OVERSEAS TERRITORY',
#        'COMOROS', 'REUNION', 'FRENCH POLYNESIA', 'UNITED KINGDOM',
#        'UNITED ARAB EMIRATES', 'PHILIPPINES', 'INDONESIA', 'CHINA',
#        'COLUMBIA', 'CAPE VERDE', 'FIJI', 'DOMINICAN REPUBLIC',
#        'CAYMAN ISLANDS', 'ARUBA', 'MOZAMBIQUE', 'PUERTO RICO', 'ITALY',
#        'ATLANTIC OCEAN', 'GREECE', 'ST. MARTIN', 'FRANCE',
#        'PAPUA NEW GUINEA', 'TRINIDAD & TOBAGO', 'KIRIBATI', 'ISRAEL',
#        'DIEGO GARCIA', 'TAIWAN', 'JAMAICA', 'PALESTINIAN TERRITORIES',
#        'GUAM', 'SEYCHELLES', 'BELIZE', 'NIGERIA', 'TONGA', 'SCOTLAND',
#        'CANADA', 'CROATIA', 'SAUDI ARABIA', 'CHILE', 'ANTIGUA', 'KENYA',
#        'RUSSIA', 'TURKS & CAICOS', 'UNITED ARAB EMIRATES (UAE)', 'AZORES',
#        'SOUTH KOREA', 'MALTA', 'VIETNAM', 'MADAGASCAR', 'PANAMA',
#        'SOMALIA', 'NEVIS', 'BRITISH VIRGIN ISLANDS', 'NORWAY', 'SENEGAL',
#        'YEMEN', 'GULF OF ADEN', 'SIERRA LEONE', 'ST. MAARTIN',
#        'GRAND CAYMAN', 'LIBERIA', 'VANUATU', 'HONDURAS', 'VENEZUELA',
#        'SRI LANKA', 'URUGUAY', 'INDIA', 'MICRONESIA', 'CARIBBEAN SEA',
#        'OKINAWA', 'TANZANIA'], dtype=object)

# %%
# 22. not sure if there is a point to change data type (?)
display(data.Year.dtype)
# Out:
# dtype('float64')

# %%
# 23. Area seems OK
#data["Area"].unique()

# %%
# 24. geting statistical overview of our table, it brings nthn since we have non numerical data
summary=data.describe().T
summary.head()
# Out:
#                  count         mean         std     min      25%     50%  \
# Year            2076.0  2009.407996    5.272681  2000.0  2005.00  2010.0
# original order  2076.0  5262.871387  599.952129  4225.0  4743.75  5262.5
#
#                     75%     max
# Year            2014.00  2018.0
# original order  5782.25  6303.0

# %%
####### TRYING DIFFERENT THINGS

data1 = data.copy()

# %%
#import datetime
#data1['year'] = pd.DatetimeIndex(data1['Year']).year
#data1.head(50)

# %%
data1.shape
# Out:
# (2076, 24)

# %%
def clean_colnames(df):
    '''Clean columns names when passing a pandas dataframe: params (df - dataframe)'''
    col_clean = []
    for col in df.columns:
        col = col.strip().upper()
        col_clean.append(col)
        
    df.columns = col_clean
    return df.columns

clean_colnames(data1)

# %%
# 25. I will now try to extract months from Date column:
#data1.sample(50)
#data["Date"].value_counts()
# I notice that most (but not all) dates are in format dd-Month-yyyy, I will try to unify cells to one date format:

# %%
# DOESN'T WORK:
#data1['Date'] = pd.to_datetime(data1['Date'])
#data1["Date"].dt.strftime("%d/%b/%y")

# %%
# DOESN'T WORK:
#import numpy as np
#import datetime
#data1['Date'] = pd.to_datetime(data1['Date'])

# %%
# DOESN'T WORK:
"""
data2 = data1.copy()
for row in data1['Date']:
    if data1.Date.str.startswith('Reported'):
            data2 = data1["Date"].str[9,:]

data2['Date'].value_counts()"""

# %%
# DOESN'T WORK:
"""
data2 = data1.copy()
lista2 =[]
for row in data1['Date']:
    re_obj = re.sub(r'Reported ', '', row)
    lista2.append(re_obj)
data2['DateCorrected'] = lista2
data2['DateCorrected'].value_counts()
data2.head()"""

# %%
# WORKS! :)
# 1. extracting "-aaa-" from strings in Date
# 2. cleaning "-"
import re
import numpy as np
months_lst = []
for row in data1['Date']:
    #re_obj = ''.join(re.findall('[^\d]',text)) #checking for letters (non numeric characters)
    #re_obj = ''.join(re.findall('[A-Za-z]{4}\-',row)).lower() #searching for months written differently than -aaa-
    re_obj = ''.join(re.findall('\-[A-Za-z]{3}\-',row)).lower()
    re_obj = re.sub('\-','',re_obj)
        
        
    #if re_obj == '':
        #re_obj = np.nan

    months_lst.append(re_obj)
# adding a column Month:
data1['Month'] = months_lst

data1["Month"].value_counts()
# Out:
# jul    238
# sep    222
# jun    207
# aug    192
# apr    188
# oct    177
# may    157
# mar    147
# jan    138
# dec    121
# nov    119
# feb    113
#         57
# Name: Month, dtype: int64

# %%
# I notice that findall didnt fid a match with 57 rows, I will check them:

# %%
data1.loc[data1['Month'] == ""]
# Out:
#        Case Number                  Date    Year          Type  \
# 86                                                 NaN  NaN  ...
# 131                                               male    M  ...
# 226                                                NaN  NaN  ...
# 370                                    Viliame Lautiki    M  ...
# 423                                   Matthew Zaccaria    M  ...
# 504                                               male    M  ...
# 556                                       Mihaela Cosa    F  ...
# 588                                               male    M  ...
# 589   Dinghy. Occupants: Jeff Kurr and Andy Casagrande  NaN  ...
# 598                                             female    F  ...
# 719                                       Jenny Oliver    F  ...
# 767                                      Sean Connelly    M  ...
# 802                                     Dylan Hapworth    M  ...
# 955                        Juan Miguel Infante Ramírez    M  ...
# 1024                                       Matt Searcy    M  ...
# 1036                                        Paul Baird    M  ...
# 1102                                    Derek Mitchell    M  ...
# 1177                                              John  NaN  ...
# 1187                                      Darryl Kriel    M  ...
# 1210                                        Daryl Zbar    M  ...
# 1239            Occupants: Luke Jones & James Sequin      M  ...
# 1292                                               NaN    M  ...
# 1298                                      Johnny Silva    M  ...
# 1299                                     Chase Edwards    M  ...
# 1314                    Patrick Walsh & Paul Damgaard     M  ...
# 1366                                        Alex Takyi  NaN  ...
# 1385                                    Sabrina Garcia    F  ...
# 1403                                              male    M  ...
# 1425                                     Renata Foucre    F  ...
# 1426                              5 Ethiopian refugees  NaN  ...
# 1447                                Miriam Picklesimer    F  ...
# 1448                                              male    M  ...
# 1465                                         Bebe Hall    F  ...
# 1466                                         Gary Hall    M  ...
# 1626                                           Unknown  NaN  ...
# 1648                                          boat x 2  NaN  ...
# 1709                                      Jack Carlsen    M  ...
# 1724                                     Richard Hatch    M  ...
# 1748                                              male    M  ...
# 1760                                        Mark Marks    M  ...
# 1761                                              male    M  ...
# 1762                                          Allen --    M  ...
# 1771                                            female    F  ...
# 1777                        a resident of Barangay Luz  NaN  ...
# 1814                                     Scott Heywood    M  ...
# 1938                                        John Davis    M  ...
# 1951                                              male    M  ...
# 1967                                            A.C.C.    F  ...
# 1973                                           Unknown  NaN  ...
# 1987                                            female    F  ...
# 2017                                               NaN  NaN  ...
# 2027                                               NaN  NaN  ...
# 2044                                               NaN  NaN  ...
# 2053                                              male    M  ...
# 2070                                       Kurt Bickel    M  ...
# 2078                     boat: occupant, Terry Winters    M  ...
#
#                                  Investigator or Source  \
# 14                                 Perth Now, 6/30/2018
# 86                                       B. Myatt, GSAF
# 131                              Tahiti Infos, 6/6/2017
# 226                                           K. Yonker
# 370                                Fiji Times, 2/8/2016
# 423                                     WFTV, 5/20/2015
# 504                 A. Brenneka, Shark Attack Survivors
# 556             M. Michaelson, Shark Research Institute
# 588                                            You Tube
# 589                                   Discovery Channel
# 598                  L. Fujimoto, Maui News, 11/29/2013
# 719                              Stuff.co.nz, 1/18/2013
# 767                                         S. Connelly
# 802                         Morning Sentinel, 4/20/2012
# 955                                  Sharksurvivors.com
# 1024                     Florida Times-Union, 7/28/2010
# 1036                             Nelson Mail, 2/23/2010
# 1102                                           WPTV.com
# 1177                                 C. Johansson, GSAF
# 1187                                          J. Little
# 1210                                 C. Johannson, GSAF
# 1239                        Hastings Observer, 8/1/2008
#
#      Case Number.2 original order Unnamed: 22 Unnamed: 23 Month
# 14      2018.05.00         6289.0         NaN         NaN
# 86      2017.09.14         6217.0         NaN         NaN
# 131     2017.06.05         6172.0         NaN         NaN
# 226     2016.09.00         6077.0         NaN         NaN
# 370     2015.09.00         5933.0         NaN         NaN
# 423     2015.05.20         5880.0         NaN         NaN
# 504     2014.09.00         5799.0         NaN         NaN
# 556     2014.05.13         5747.0         NaN         NaN
# 588   2014.00.00.b         5715.0         NaN         NaN
# 589     2014.00.00         5714.0         NaN         NaN
# 598     2013.11.29         5705.0         NaN         NaN
# 719     2012.12.00         5584.0         NaN         NaN
# 767   2012.07.07.c         5536.0         NaN         NaN
# 802     2012.04.00         5501.0         NaN         NaN
# 955   2011.01.12.R         5348.0         NaN         NaN
# 1024    2010.06.00         5279.0         NaN         NaN
# 1036    2010.02.19         5267.0         NaN         NaN
# 1102    2009.07.31         5201.0         NaN         NaN
# 1177    2009.01.00         5126.0         NaN         NaN
# 1187    2008.12.00         5116.0         NaN         NaN
# 1210    2008.09.00         5093.0         NaN         NaN
# 1239    2008.07.00         5064.0         NaN         NaN
# 1292    2008.01.30         5011.0         NaN         NaN
# 1298  2008.00.00.b         5005.0         NaN         NaN
# 1299  2008.00.00.a         5004.0         NaN         NaN
# 1314    2007.11.00         4989.0         NaN         NaN
# 1366    2007.07.00         4937.0         NaN         NaN
# 1385    2007.05.00         4918.0         NaN         NaN
# 1403    2007.02.00         4900.0         NaN         NaN
# 1425  2006.10.00.b         4878.0         NaN         NaN
# 1426  2006.10.00.a         4877.0         NaN         NaN
# 1447  2006.08.00.b         4856.0         NaN         NaN
# 1448  2006.08.00.a         4855.0         NaN         NaN
# 1465  2006.06.30.b         4838.0         NaN         NaN
# 1466  2006.06.30.a         4837.0         NaN         NaN
# 1626    2004.11.00         4677.0         NaN         NaN
# 1648    2004.08.00         4655.0         NaN         NaN
# 1709    2004.00.00         4594.0         NaN         NaN
# 1724    2003.11.00         4579.0         NaN         NaN
# 1748    2003.09.00         4555.0         NaN         NaN
# 1760  2003.07.00.c         4543.0         NaN         NaN
# 1761  2003.07.00.b         4542.0         NaN         NaN
# 1762  2003.07.00.a         4541.0         NaN         NaN
# 1771    2003.06.00         4532.0         NaN         NaN
# 1777    2003.05.00         4526.0         NaN         NaN
# 1814  2002.11.00.a         4489.0         NaN         NaN
# 1938    2001.07.00         4365.0         NaN         NaN
# 1951    2001.05.00         4352.0         NaN         NaN
# 1967  2001.04.02.b         4336.0         NaN         NaN
# 1973    2001.03.00         4330.0         NaN         NaN
# 1987    2000.12.00         4316.0         NaN         NaN
# 2017  2000.09.00.b         4286.0         NaN         NaN
# 2027    2000.08.00         4276.0         NaN         NaN
# 2044    2000.07.00         4259.0         NaN         NaN
# 2053    2000.06.00         4250.0         NaN         NaN
# 2070    2000.03.00         4233.0         NaN         NaN
# 2078    2000.00.00         4225.0         NaN         NaN
#
# [57 rows x 25 columns]

# %%
# I notice that many of them can be easily corrected with another findall:

# %%
data2 = data1.copy()
months_lst = []
for row in data2['Date']:
    re_obj = ''.join(re.findall('[A-Za-z]{3}\-',row)).lower()
    re_obj = re.sub('\-','',re_obj)
        
        
    #if re_obj == '':
        #re_obj = np.nan

    months_lst.append(re_obj)

data2['Month'] = months_lst

data2["Month"].value_counts()
# Out:
# jul    245
# sep    229
# jun    210
# aug    196
# apr    189
# oct    179
# may    160
# mar    149
# jan    139
# dec    123
# nov    122
# feb    115
#         17
# uly      2
# mer      1
# Name: Month, dtype: int64

# %%
# Great, I only have 17 unmatched rows and 3 matched, but need some cleaning
# let s have a lok at these 17 unmatched rows:

# %%
data2.loc[data2['Month'] == ""]
# Out:
#        Case Number                  Date    Year        Type  \
# 14      2018.05.00              May 2018  2018.0    Provoked
# 131     2017.06.05            2017.06.05  2017.0  Unprovoked
# 423     2015.05.20            20-May2015  2015.0  Unprovoked
# 556     2014.05.13            13-May2014  2014.0  Unprovoked
# 588   2014.00.00.b                  2014  2014.0  Unprovoked
# 589     2014.00.00                  2014  2014.0     Boating
# 598     2013.11.29            29-Nov2013  2013.0  Unprovoked
# 719     2012.12.00         December 2012  2012.0  Unprovoked
# 955   2011.01.12.R  Reported 12-Jan 2011  2011.0  Unprovoked
# 1292    2008.01.30            2008.01.30  2008.0    Provoked
# 1298  2008.00.00.b             Fall 2008  2008.0    Provoked
# 1314    2007.11.00         November 2011  2007.0     Invalid
# 1465  2006.06.30.b             July 2006  2006.0  Unprovoked
# 1466  2006.06.30.a             July 2006  2006.0  Unprovoked
# 1709    2004.00.00                  2004  2004.0  Unprovoked
# 1967  2001.04.02.b            02-Ap-2001  2001.0  Unprovoked
# 2078    2000.00.00                  2000  2000.0        Boat
#
#                Country                 Area  \
# 14           AUSTRALIA    Westerm Australia
# 131   FRENCH POLYNESIA            Marquesas
# 423                USA              Florida
# 556                USA              Florida
# 588                USA               Hawaii
# 589        NEW ZEALAND                  NaN
# 598                USA               Hawaii
# 719        NEW ZEALAND         South Island
# 955             MEXICO         Quintana Roo
# 1292             JAPAN            Tokyo Bay
# 1298               USA              Florida
# 1314            MEXICO      Baja California
# 1465               USA              Florida
# 1466               USA              Florida
# 1709         AUSTRALIA    Western Australia
# 1967            BRAZIL  Rio Grande de Norte
# 2078               USA              Florida
#
#                                Location  \
# 14                           Dugong Bay
# 131          Atuona Bay, Hiva Oa Island
# 423    New Smyrna Beach, Volusia County
# 556    Jacksonville Beach, Duval County
# 588                                 NaN
# 589                      Stewart Island
# 598        Keawekapu Beach, Kihei, Maui
# 719              Sunday Cove, Fiordland
# 955                             Xcalak
# 1292                                NaN
# 1298  Off Fort Pierce, St. Lucie County
# 1314                   Guadalupe Island
# 1465        Florida Keys, Monroe County
# 1466        Florida Keys, Monroe County
# 1709                      Redgate Beach
# 1967            Praia de Camapum, Macau
# 2078            Boca Grande, Lee County
#
#                                       Activity  \
# 14                              Feeding sharks
# 131                                    Surfing
# 423                                    Surfing
# 556                                     Wading
# 588   Free diving / Photographing pilot whales
# 589                      Filming a documentary
# 598                                 Snorkeling
# 719                               Scuba diving
# 955                    Attempting to fix motor
# 1292                                    Diving
# 1298                       Fishing for snapper
# 1314                              Shark diving
# 1465                              Spearfishing
# 1466                              Spearfishing
# 1709                                   Surfing
# 1967                                     Batin
# 2078                        Fishing for tarpon
#
#                                                   Name Sex   ...  \
# 14                                     Melisa Brunning    F  ...
# 131                                               male    M  ...
# 423                                   Matthew Zaccaria    M  ...
# 556                                       Mihaela Cosa    F  ...
# 588                                               male    M  ...
# 589   Dinghy. Occupants: Jeff Kurr and Andy Casagrande  NaN  ...
# 598                                             female    F  ...
# 719                                       Jenny Oliver    F  ...
# 955                        Juan Miguel Infante Ramírez    M  ...
# 1292                                               NaN    M  ...
# 1298                                      Johnny Silva    M  ...
# 1314                    Patrick Walsh & Paul Damgaard     M  ...
# 1465                                         Bebe Hall    F  ...
# 1466                                         Gary Hall    M  ...
# 1709                                      Jack Carlsen    M  ...
# 1967                                            A.C.C.    F  ...
# 2078                     boat: occupant, Terry Winters    M  ...
#
#                        Investigator or Source  \
# 14                       Perth Now, 6/30/2018
# 131                    Tahiti Infos, 6/6/2017
# 423                           WFTV, 5/20/2015
# 556   M. Michaelson, Shark Research Institute
# 588                                  You Tube
# 589                         Discovery Channel
# 598        L. Fujimoto, Maui News, 11/29/2013
# 719                    Stuff.co.nz, 1/18/2013
# 955                        Sharksurvivors.com
# 1292                               L Compagno
# 1298              Extremecoast.com/ 1/30/2009
# 1314                               Today Show
# 1465     Swimming World Magazine, 2 July 2006
# 1466     Swimming World Magazine, 2 July 2006
# 1709                               J. Carlsen
# 1967                              M. Szpilman
# 2078           B. Stout, News-Press, 7/2/2005
#
#                                    pdf  \
# 14             2018.05.00-Brunning.pdf
# 131     2017.06.05-FrenchPolynesia.pdf
# 423            2015.05.20-Zaccaria.pdf
# 556                2014.05.13-Cosa.pdf
# 588   2014.00.00.b-OceanicWhitetip.pdf
# 589           2014.00.00-Jeff-Andy.pdf
# 598                2013.11.29-Maui.pdf
# 719              2012.12.00-Oliver.pdf
# 955           2011.01.12.R-Infante.pdf
# 1292        2008.01.30-GoblinShark.pdf
# 1298            2008.00.00.b-Silva.pdf
# 1314               2007.11.00-cage.pdf
# 1465        2006.06.30.b-Bebe-Hall.pdf
# 1466         2006.06.30.a-GaryHall.pdf
# 1709            2004.00.00-Carlsen.pdf
# 1967              2001.04.02.b-ACC.pdf
# 2078     2000.00.00-BocaGrandeBoat.pdf
#
#                                            href formula  \
# 14    http://sharkattackfile.net/spreadsheets/pdf_di...
# 131   http://sharkattackfile.net/spreadsheets/pdf_di...
# 423   http://sharkattackfile.net/spreadsheets/pdf_di...
# 556   http://sharkattackfile.net/spreadsheets/pdf_di...
# 588   http://sharkattackfile.net/spreadsheets/pdf_di...
# 589   http://sharkattackfile.net/spreadsheets/pdf_di...
# 598   http://sharkattackfile.net/spreadsheets/pdf_di...
# 719   http://sharkattackfile.net/spreadsheets/pdf_di...
# 955   http://sharkattackfile.net/spreadsheets/pdf_di...
# 1292  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1298  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1314  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1465  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1466  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1709  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1967  http://sharkattackfile.net/spreadsheets/pdf_di...
# 2078  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                    href Case Number.1  \
# 14    http://sharkattackfile.net/spreadsheets/pdf_di...    2018.05.00
# 131   http://sharkattackfile.net/spreadsheets/pdf_di...    2017.06.05
# 423   http://sharkattackfile.net/spreadsheets/pdf_di...    2015.05.20
# 556   http://sharkattackfile.net/spreadsheets/pdf_di...    2014.05.13
# 588   http://sharkattackfile.net/spreadsheets/pdf_di...  2014.00.00.b
# 589   http://sharkattackfile.net/spreadsheets/pdf_di...    2014.00.00
# 598   http://sharkattackfile.net/spreadsheets/pdf_di...    2013.11.29
# 719   http://sharkattackfile.net/spreadsheets/pdf_di...    2012.12.00
# 955   http://sharkattackfile.net/spreadsheets/pdf_di...  2011.01.12.R
# 1292  http://sharkattackfile.net/spreadsheets/pdf_di...    2008.01.30
# 1298  http://sharkattackfile.net/spreadsheets/pdf_di...  2008.00.00.b
# 1314  http://sharkattackfile.net/spreadsheets/pdf_di...    2007.11.00
# 1465  http://sharkattackfile.net/spreadsheets/pdf_di...  2006.06.30.b
# 1466  http://sharkattackfile.net/spreadsheets/pdf_di...  2006.06.30.a
# 1709  http://sharkattackfile.net/spreadsheets/pdf_di...    2004.00.00
# 1967  http://sharkattackfile.net/spreadsheets/pdf_di...  2001.04.02.b
# 2078  http://sharkattackfile.net/spreadsheets/pdf_di...    2000.00.00
#
#      Case Number.2 original order Unnamed: 22 Unnamed: 23 Month
# 14      2018.05.00         6289.0         NaN         NaN
# 131     2017.06.05         6172.0         NaN         NaN
# 423     2015.05.20         5880.0         NaN         NaN
# 556     2014.05.13         5747.0         NaN         NaN
# 588   2014.00.00.b         5715.0         NaN         NaN
# 589     2014.00.00         5714.0         NaN         NaN
# 598     2013.11.29         5705.0         NaN         NaN
# 719     2012.12.00         5584.0         NaN         NaN
# 955   2011.01.12.R         5348.0         NaN         NaN
# 1292    2008.01.30         5011.0         NaN         NaN
# 1298  2008.00.00.b         5005.0         NaN         NaN
# 1314    2007.11.00         4989.0         NaN         NaN
# 1465  2006.06.30.b         4838.0         NaN         NaN
# 1466  2006.06.30.a         4837.0         NaN         NaN
# 1709    2004.00.00         4594.0         NaN         NaN
# 1967  2001.04.02.b         4336.0         NaN         NaN
# 2078    2000.00.00         4225.0         NaN         NaN
#
# [17 rows x 25 columns]

# %%
# I wanted to clean with same method one more time, but it would overrate my previous condition
# so I tried to cut these 17 as a separate dataframe and do the cleaning on it,
# but there is an error to handle and it s for the matter of 4 rows, so decided to do it manually :)

# %%
data3 = data2.loc[data2['Month'] == ""]
data3.head(20)
# Out:
#        Case Number                  Date    Year        Type  \
# 14      2018.05.00              May 2018  2018.0    Provoked
# 131     2017.06.05            2017.06.05  2017.0  Unprovoked
# 423     2015.05.20            20-May2015  2015.0  Unprovoked
# 556     2014.05.13            13-May2014  2014.0  Unprovoked
# 588   2014.00.00.b                  2014  2014.0  Unprovoked
# 589     2014.00.00                  2014  2014.0     Boating
# 598     2013.11.29            29-Nov2013  2013.0  Unprovoked
# 719     2012.12.00         December 2012  2012.0  Unprovoked
# 955   2011.01.12.R  Reported 12-Jan 2011  2011.0  Unprovoked
# 1292    2008.01.30            2008.01.30  2008.0    Provoked
# 1298  2008.00.00.b             Fall 2008  2008.0    Provoked
# 1314    2007.11.00         November 2011  2007.0     Invalid
# 1465  2006.06.30.b             July 2006  2006.0  Unprovoked
# 1466  2006.06.30.a             July 2006  2006.0  Unprovoked
# 1709    2004.00.00                  2004  2004.0  Unprovoked
# 1967  2001.04.02.b            02-Ap-2001  2001.0  Unprovoked
# 2078    2000.00.00                  2000  2000.0        Boat
#
#                Country                 Area  \
# 14           AUSTRALIA    Westerm Australia
# 131   FRENCH POLYNESIA            Marquesas
# 423                USA              Florida
# 556                USA              Florida
# 588                USA               Hawaii
# 589        NEW ZEALAND                  NaN
# 598                USA               Hawaii
# 719        NEW ZEALAND         South Island
# 955             MEXICO         Quintana Roo
# 1292             JAPAN            Tokyo Bay
# 1298               USA              Florida
# 1314            MEXICO      Baja California
# 1465               USA              Florida
# 1466               USA              Florida
# 1709         AUSTRALIA    Western Australia
# 1967            BRAZIL  Rio Grande de Norte
# 2078               USA              Florida
#
#                                Location  \
# 14                           Dugong Bay
# 131          Atuona Bay, Hiva Oa Island
# 423    New Smyrna Beach, Volusia County
# 556    Jacksonville Beach, Duval County
# 588                                 NaN
# 589                      Stewart Island
# 598        Keawekapu Beach, Kihei, Maui
# 719              Sunday Cove, Fiordland
# 955                             Xcalak
# 1292                                NaN
# 1298  Off Fort Pierce, St. Lucie County
# 1314                   Guadalupe Island
# 1465        Florida Keys, Monroe County
# 1466        Florida Keys, Monroe County
# 1709                      Redgate Beach
# 1967            Praia de Camapum, Macau
# 2078            Boca Grande, Lee County
#
#                                       Activity  \
# 14                              Feeding sharks
# 131                                    Surfing
# 423                                    Surfing
# 556                                     Wading
# 588   Free diving / Photographing pilot whales
# 589                      Filming a documentary
# 598                                 Snorkeling
# 719                               Scuba diving
# 955                    Attempting to fix motor
# 1292                                    Diving
# 1298                       Fishing for snapper
# 1314                              Shark diving
# 1465                              Spearfishing
# 1466                              Spearfishing
# 1709                                   Surfing
# 1967                                     Batin
# 2078                        Fishing for tarpon
#
#                                                   Name Sex   ...  \
# 14                                     Melisa Brunning    F  ...
# 131                                               male    M  ...
# 423                                   Matthew Zaccaria    M  ...
# 556                                       Mihaela Cosa    F  ...
# 588                                               male    M  ...
# 589   Dinghy. Occupants: Jeff Kurr and Andy Casagrande  NaN  ...
# 598                                             female    F  ...
# 719                                       Jenny Oliver    F  ...
# 955                        Juan Miguel Infante Ramírez    M  ...
# 1292                                               NaN    M  ...
# 1298                                      Johnny Silva    M  ...
# 1314                    Patrick Walsh & Paul Damgaard     M  ...
# 1465                                         Bebe Hall    F  ...
# 1466                                         Gary Hall    M  ...
# 1709                                      Jack Carlsen    M  ...
# 1967                                            A.C.C.    F  ...
# 2078                     boat: occupant, Terry Winters    M  ...
#
#                        Investigator or Source  \
# 14                       Perth Now, 6/30/2018
# 131                    Tahiti Infos, 6/6/2017
# 423                           WFTV, 5/20/2015
# 556   M. Michaelson, Shark Research Institute
# 588                                  You Tube
# 589                         Discovery Channel
# 598        L. Fujimoto, Maui News, 11/29/2013
# 719                    Stuff.co.nz, 1/18/2013
# 955                        Sharksurvivors.com
# 1292                               L Compagno
# 1298              Extremecoast.com/ 1/30/2009
# 1314                               Today Show
# 1465     Swimming World Magazine, 2 July 2006
# 1466     Swimming World Magazine, 2 July 2006
# 1709                               J. Carlsen
# 1967                              M. Szpilman
# 2078           B. Stout, News-Press, 7/2/2005
#
#                                    pdf  \
# 14             2018.05.00-Brunning.pdf
# 131     2017.06.05-FrenchPolynesia.pdf
# 423            2015.05.20-Zaccaria.pdf
# 556                2014.05.13-Cosa.pdf
# 588   2014.00.00.b-OceanicWhitetip.pdf
# 589           2014.00.00-Jeff-Andy.pdf
# 598                2013.11.29-Maui.pdf
# 719              2012.12.00-Oliver.pdf
# 955           2011.01.12.R-Infante.pdf
# 1292        2008.01.30-GoblinShark.pdf
# 1298            2008.00.00.b-Silva.pdf
# 1314               2007.11.00-cage.pdf
# 1465        2006.06.30.b-Bebe-Hall.pdf
# 1466         2006.06.30.a-GaryHall.pdf
# 1709            2004.00.00-Carlsen.pdf
# 1967              2001.04.02.b-ACC.pdf
# 2078     2000.00.00-BocaGrandeBoat.pdf
#
#                                            href formula  \
# 14    http://sharkattackfile.net/spreadsheets/pdf_di...
# 131   http://sharkattackfile.net/spreadsheets/pdf_di...
# 423   http://sharkattackfile.net/spreadsheets/pdf_di...
# 556   http://sharkattackfile.net/spreadsheets/pdf_di...
# 588   http://sharkattackfile.net/spreadsheets/pdf_di...
# 589   http://sharkattackfile.net/spreadsheets/pdf_di...
# 598   http://sharkattackfile.net/spreadsheets/pdf_di...
# 719   http://sharkattackfile.net/spreadsheets/pdf_di...
# 955   http://sharkattackfile.net/spreadsheets/pdf_di...
# 1292  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1298  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1314  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1465  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1466  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1709  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1967  http://sharkattackfile.net/spreadsheets/pdf_di...
# 2078  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                    href Case Number.1  \
# 14    http://sharkattackfile.net/spreadsheets/pdf_di...    2018.05.00
# 131   http://sharkattackfile.net/spreadsheets/pdf_di...    2017.06.05
# 423   http://sharkattackfile.net/spreadsheets/pdf_di...    2015.05.20
# 556   http://sharkattackfile.net/spreadsheets/pdf_di...    2014.05.13
# 588   http://sharkattackfile.net/spreadsheets/pdf_di...  2014.00.00.b
# 589   http://sharkattackfile.net/spreadsheets/pdf_di...    2014.00.00
# 598   http://sharkattackfile.net/spreadsheets/pdf_di...    2013.11.29
# 719   http://sharkattackfile.net/spreadsheets/pdf_di...    2012.12.00
# 955   http://sharkattackfile.net/spreadsheets/pdf_di...  2011.01.12.R
# 1292  http://sharkattackfile.net/spreadsheets/pdf_di...    2008.01.30
# 1298  http://sharkattackfile.net/spreadsheets/pdf_di...  2008.00.00.b
# 1314  http://sharkattackfile.net/spreadsheets/pdf_di...    2007.11.00
# 1465  http://sharkattackfile.net/spreadsheets/pdf_di...  2006.06.30.b
# 1466  http://sharkattackfile.net/spreadsheets/pdf_di...  2006.06.30.a
# 1709  http://sharkattackfile.net/spreadsheets/pdf_di...    2004.00.00
# 1967  http://sharkattackfile.net/spreadsheets/pdf_di...  2001.04.02.b
# 2078  http://sharkattackfile.net/spreadsheets/pdf_di...    2000.00.00
#
#      Case Number.2 original order Unnamed: 22 Unnamed: 23 Month
# 14      2018.05.00         6289.0         NaN         NaN
# 131     2017.06.05         6172.0         NaN         NaN
# 423     2015.05.20         5880.0         NaN         NaN
# 556     2014.05.13         5747.0         NaN         NaN
# 588   2014.00.00.b         5715.0         NaN         NaN
# 589     2014.00.00         5714.0         NaN         NaN
# 598     2013.11.29         5705.0         NaN         NaN
# 719     2012.12.00         5584.0         NaN         NaN
# 955   2011.01.12.R         5348.0         NaN         NaN
# 1292    2008.01.30         5011.0         NaN         NaN
# 1298  2008.00.00.b         5005.0         NaN         NaN
# 1314    2007.11.00         4989.0         NaN         NaN
# 1465  2006.06.30.b         4838.0         NaN         NaN
# 1466  2006.06.30.a         4837.0         NaN         NaN
# 1709    2004.00.00         4594.0         NaN         NaN
# 1967  2001.04.02.b         4336.0         NaN         NaN
# 2078    2000.00.00         4225.0         NaN         NaN
#
# [17 rows x 25 columns]

# %%
"""# another cleaning with findall:
months_lst = []
for row in data3['Date']:
    re_obj = ''.join(re.findall('\-[A-Za-z]{3}',row)).lower()
    re_obj = re.sub('\-','',re_obj)
        
        
    #if re_obj == '':
        #re_obj = np.nan

    months_lst.append(re_obj)

data3['Month'] = months_lst

data3["Month"].value_counts()


Looong error about using a copy of a piece of the data"""

# %%
data4 = data2.copy()
#data4["Date"] = data4["Date"].str.replace('May 2018', 'May')
#data4.loc[data4['Month'] == ""]

# %%
# I will manually change these 17 rows:
data4['Month'] = np.where(data4['Date'] == "May", "may", data4['Month'])
data4['Month'] = np.where(data4['Date'] == "2017.06.05", "jun", data4['Month'])
data4['Month'] = np.where(data4['Date'] == "20-May2015", "may", data4['Month'])
data4['Month'] = np.where(data4['Date'] == "13-May2014", "may", data4['Month'])
data4['Month'] = np.where(data4['Date'] == "29-Nov2013", "nov", data4['Month'])
data4['Month'] = np.where(data4['Date'] == "December 2012", "dec", data4['Month'])
data4['Month'] = np.where(data4['Date'] == "Reported 12-Jan 2011", "jan", data4['Month'])
data4['Month'] = np.where(data4['Date'] == "2008.01.30", "jan", data4['Month'])
data4['Month'] = np.where(data4['Date'] == "November 2011", "nov", data4['Month'])
data4['Month'] = np.where(data4['Date'] == "July 2006", "jul", data4['Month'])
data4['Month'] = np.where(data4['Date'] == "02-Ap-2001", "apr", data4['Month'])
#data4['Month'] = np.where(data4['Date'] == "uly", "jul", data4['Month'])



data4["Month"].value_counts()
# Out:
# jul    247
# sep    229
# jun    211
# aug    196
# apr    190
# oct    179
# may    162
# mar    149
# jan    141
# nov    124
# dec    124
# feb    115
#          6
# uly      2
# mer      1
# Name: Month, dtype: int64

# %%
data4.loc[data4['Month'] == ""]
# Out:
#        Case Number       Date    Year        Type      Country  \
# 14      2018.05.00   May 2018  2018.0    Provoked    AUSTRALIA
# 588   2014.00.00.b       2014  2014.0  Unprovoked          USA
# 589     2014.00.00       2014  2014.0     Boating  NEW ZEALAND
# 1298  2008.00.00.b  Fall 2008  2008.0    Provoked          USA
# 1709    2004.00.00       2004  2004.0  Unprovoked    AUSTRALIA
# 2078    2000.00.00       2000  2000.0        Boat          USA
#
#                    Area                           Location  \
# 14    Westerm Australia                         Dugong Bay
# 588              Hawaii                                NaN
# 589                 NaN                     Stewart Island
# 1298            Florida  Off Fort Pierce, St. Lucie County
# 1709  Western Australia                      Redgate Beach
# 2078            Florida            Boca Grande, Lee County
#
#                                       Activity  \
# 14                              Feeding sharks
# 588   Free diving / Photographing pilot whales
# 589                      Filming a documentary
# 1298                       Fishing for snapper
# 1709                                   Surfing
# 2078                        Fishing for tarpon
#
#                                                   Name Sex   ...  \
# 14                                     Melisa Brunning    F  ...
# 588                                               male    M  ...
# 589   Dinghy. Occupants: Jeff Kurr and Andy Casagrande  NaN  ...
# 1298                                      Johnny Silva    M  ...
# 1709                                      Jack Carlsen    M  ...
# 2078                     boat: occupant, Terry Winters    M  ...
#
#               Investigator or Source                               pdf  \
# 14              Perth Now, 6/30/2018           2018.05.00-Brunning.pdf
# 588                         You Tube  2014.00.00.b-OceanicWhitetip.pdf
# 589                Discovery Channel          2014.00.00-Jeff-Andy.pdf
# 1298     Extremecoast.com/ 1/30/2009            2008.00.00.b-Silva.pdf
# 1709                      J. Carlsen            2004.00.00-Carlsen.pdf
# 2078  B. Stout, News-Press, 7/2/2005     2000.00.00-BocaGrandeBoat.pdf
#
#                                            href formula  \
# 14    http://sharkattackfile.net/spreadsheets/pdf_di...
# 588   http://sharkattackfile.net/spreadsheets/pdf_di...
# 589   http://sharkattackfile.net/spreadsheets/pdf_di...
# 1298  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1709  http://sharkattackfile.net/spreadsheets/pdf_di...
# 2078  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                    href Case Number.1  \
# 14    http://sharkattackfile.net/spreadsheets/pdf_di...    2018.05.00
# 588   http://sharkattackfile.net/spreadsheets/pdf_di...  2014.00.00.b
# 589   http://sharkattackfile.net/spreadsheets/pdf_di...    2014.00.00
# 1298  http://sharkattackfile.net/spreadsheets/pdf_di...  2008.00.00.b
# 1709  http://sharkattackfile.net/spreadsheets/pdf_di...    2004.00.00
# 2078  http://sharkattackfile.net/spreadsheets/pdf_di...    2000.00.00
#
#      Case Number.2 original order Unnamed: 22 Unnamed: 23 Month
# 14      2018.05.00         6289.0         NaN         NaN
# 588   2014.00.00.b         5715.0         NaN         NaN
# 589     2014.00.00         5714.0         NaN         NaN
# 1298  2008.00.00.b         5005.0         NaN         NaN
# 1709    2004.00.00         4594.0         NaN         NaN
# 2078    2000.00.00         4225.0         NaN         NaN
#
# [6 rows x 25 columns]

# %%
# I will set those to "UNKNOWN"

data4['Month'] = np.where(data4['Date'] == "2014", "UNKNOWN", data4['Month'])
data4['Month'] = np.where(data4['Date'] == "2014", "UNKNOWN", data4['Month'])
data4['Month'] = np.where(data4['Date'] == "Fall 2008", "UNKNOWN", data4['Month'])
data4['Month'] = np.where(data4['Date'] == "2004", "UNKNOWN", data4['Month'])
data4['Month'] = np.where(data4['Date'] == "2000", "UNKNOWN", data4['Month'])

data4["Month"].value_counts()
# Out:
# jul        247
# sep        229
# jun        211
# aug        196
# apr        190
# oct        179
# may        162
# mar        149
# jan        141
# nov        124
# dec        124
# feb        115
# UNKNOWN      5
# uly          2
# mer          1
#              1
# Name: Month, dtype: int64

# %%
# I will check what is in "uly" row:
data4.loc[data4['Month'] == "uly"]
# Out:
#        Case Number          Date    Year        Type  Country           Area  \
# 767   2012.07.07.c  07-July-2012  2012.0  Unprovoked  BAHAMAS      Eleuthera
# 1102    2009.07.31  31-July-2009  2009.0  Unprovoked  BAHAMAS  Abaco Islands
#
#          Location      Activity            Name Sex   ...  \
# 767           NaN  Spearfishing   Sean Connelly    M  ...
# 1102  Spanish Cay  Spearfishing  Derek Mitchell    M  ...
#
#      Investigator or Source                        pdf  \
# 767             S. Connelly  2012.07.07.c-Connelly.pdf
# 1102               WPTV.com    2009.07.31-Mitchell.pdf
#
#                                            href formula  \
# 767   http://sharkattackfile.net/spreadsheets/pdf_di...
# 1102  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                    href Case Number.1  \
# 767   http://sharkattackfile.net/spreadsheets/pdf_di...  2012.07.07.c
# 1102  http://sharkattackfile.net/spreadsheets/pdf_di...    2009.07.31
#
#      Case Number.2 original order Unnamed: 22 Unnamed: 23 Month
# 767   2012.07.07.c         5536.0         NaN         NaN   uly
# 1102    2009.07.31         5201.0         NaN         NaN   uly
#
# [2 rows x 25 columns]

# %%
#changing those to jul:
data4['Month'] = np.where(data4['Date'] == "07-July-2012", "jul", data4['Month'])
data4['Month'] = np.where(data4['Date'] == "31-July-2009", "jul", data4['Month'])

data4["Month"].value_counts()
# Out:
# jul        249
# sep        229
# jun        211
# aug        196
# apr        190
# oct        179
# may        163
# mar        149
# jan        141
# nov        124
# dec        124
# feb        115
# UNKNOWN      5
# mer          1
# Name: Month, dtype: int64

# %%
#checking the "mer" row:
data4.loc[data4['Month'] == "mer"]
# Out:
#        Case Number         Date    Year        Type Country             Area  \
# 1299  2008.00.00.a  Summer-2008  2008.0  Unprovoked  MEXICO  Baja California
#
#                Location Activity           Name Sex   ...  \
# 1299  Playas de Tijuana  Surfing  Chase Edwards    M  ...
#
#           Investigator or Source                       pdf  \
# 1299  San Diego Reader, 1/7/2009  2008.00.00.a-Edwards.pdf
#
#                                            href formula  \
# 1299  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                    href Case Number.1  \
# 1299  http://sharkattackfile.net/spreadsheets/pdf_di...  2008.00.00.a
#
#      Case Number.2 original order Unnamed: 22 Unnamed: 23 Month
# 1299  2008.00.00.a         5004.0         NaN         NaN   mer
#
# [1 rows x 25 columns]

# %%
#changing it to UNKNOWN:
data4['Month'] = np.where(data4['Date'] == "Summer-2008", "UNKNOWN", data4['Month'])
data4["Month"].value_counts()
# Out:
# jul        249
# sep        229
# jun        211
# aug        196
# apr        190
# oct        179
# may        163
# mar        149
# jan        141
# nov        124
# dec        124
# feb        115
# UNKNOWN      6
# Name: Month, dtype: int64

# %%
# Now I will check the results of cleaning my dataframe:

data4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2076 entries, 0 to 2078
# Data columns (total 25 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Case Number             2076 non-null   object
#  1   Date                    2076 non-null   object
#  2   Year                    2076 non-null   float64
#  3   Type                    2074 non-null   object
#  4   Country                 2076 non-null   object
#  5   Area                    1988 non-null   object
#  6   Location                1991 non-null   object
#  7   Activity                1985 non-null   object
#  8   Name                    2043 non-null   object
#  9   Sex                     1972 non-null   object
#  10  Age                     1551 non-null   object
#  11  Injury                  2074 non-null   object
#  12  Fatality                2076 non-null   object
#  13  Time                    1478 non-null   object
#  14  Species                 1368 non-null   object
#  15  Investigator or Source  2070 non-null   object
#  16  pdf                     2076 non-null   object
#  17  href formula            2076 non-null   object
#  18  href                    2076 non-null   object
#  19  Case Number.1           2076 non-null   object
#  20  Case Number.2           2076 non-null   object
#  21  original order          2076 non-null   float64
#  22  Unnamed: 22             1 non-null      object
#  23  Unnamed: 23             0 non-null      object
#  24  Month                   2076 non-null   object
# dtypes: float64(2), object(23)
# memory usage: 421.7+ KB

# %%
# I will drop all unnecessary columns:
data4.columns
# Out:
# Index(['Case Number', 'Date', 'Year', 'Type', 'Country', 'Area', 'Location',
#        'Activity', 'Name', 'Sex ', 'Age', 'Injury', 'Fatality', 'Time',
#        'Species ', 'Investigator or Source', 'pdf', 'href formula', 'href',
#        'Case Number.1', 'Case Number.2', 'original order', 'Unnamed: 22',
#        'Unnamed: 23', 'Month'],
#       dtype='object')

# %%
data4.shape
# Out:
# (2076, 25)

# %%
cols_to_drop=['Case Number', 'Date', 'Type','Activity', 'Name', 'Sex ', 'Age', 'Injury', 'Time','Species ', 'Investigator or Source', 'pdf', 'href formula', 'href',
       'Case Number.1', 'Case Number.2', 'original order', 'Unnamed: 22',
       'Unnamed: 23']
data4 = data4.drop(cols_to_drop, axis=1)
data4.shape
# Out:
# (2076, 6)

# %%
data4.sample()
# Out:
#         Year Month    Country             Area                 Location  \
# 1309  2007.0   nov  AUSTRALIA  New South Wales  Wategos Beach, Byon Bay
#
#      Fatality
# 1309        N

# %%
# Looks ok, I will just change the column order to have Month next to Year:

# data4.insert(1, 'Month', data4.Month(1)) #doesn't work wit 1 as value(series), dont know why
data4 = data4[["Year", "Month", "Country","Area","Location", "Fatality"]]
data4.head()
# Out:
#      Year Month    Country             Area                        Location  \
# 0  2018.0   jun        USA       California     Oceanside, San Diego County
# 1  2018.0   jun        USA          Georgia  St. Simon Island, Glynn County
# 2  2018.0   jun        USA           Hawaii                    Habush, Oahu
# 3  2018.0   jun  AUSTRALIA  New South Wales              Arrawarra Headland
# 4  2018.0   jun     MEXICO           Colima                        La Ticla
#
#   Fatality
# 0        N
# 1        N
# 2        N
# 3        N
# 4        N

# %%
# OK, I will export my cleaned data to csv:

os.chdir('C:/Users/Kasia/TEST/806_Repo/Labs/module_1/Pipelines-Project')
data4.to_csv("attacks_cleaned")
